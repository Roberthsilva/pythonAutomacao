# %%
# !pip install pyautogui

# %%
import pyautogui as py;
import pyperclip;
import time;

py.PAUSE = 1;
#1 Entrar no sistema da empresa(exemplo: link do drive)
py.hotkey("ctrl", "t");
pyperclip.copy("https://drive.google.com/drive/folders/156rEavwHNrkbQTrrDKglyc8I-W30OV4m?usp=sharing");
py.hotkey("ctrl", "v");
py.press("enter");

time.sleep(3)
#2 Procurar base de vendas nos sistema
py.click(x=357, y=356);
time.sleep(3)
#3 Fazer download da base de dados
py.click(x=1155, y=188);
time.sleep(1);
py.click(x=997, y=594);

# %%
#4 Transferir base de dados pra python
import pandas as pd;

tabela = pd.read_excel(r"C:\Users\rober\Downloads\Vendas - Dez.xlsx");
display(tabela);
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#5 Calcular dados da empresa
faturamento = tabela["Valor Final"].sum();
print(faturamento);
quantidade = tabela["Quantidade"].sum();
print(quantidade);
# Out:
# 2917311
# 15227

# %%
#6 Enviar e-mail para empresa com relatório de vendas
# Abrir aba
py.hotkey("ctrl", "t");
# Entrar no link do e-mail
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox");
py.hotkey("ctrl", "v");
py.press("enter");
time.sleep(3);
# Preencher informações do e-mail
py.click(x=58, y=195);
py.write("galoobennet@gmail.com");
py.press("tab");
py.press("tab");
pyperclip.copy("Relatório de vendas");
py.hotkey("ctrl", "v");
py.press("tab");

texto = f"""Prezados, estou encaminhando o faturamento e a quantidade de vendas do mês:
faturamento:R$ {faturamento:,.2f}
Quantidade de vendas: {quantidade:,}

Tenha uma boa noite, em casos de dúvidas, entre em contato!
"""

pyperclip.copy(texto);
py.hotkey("ctrl", "v");

# Enviar e-mail
py.hotkey("ctrl","enter");

# %%
time.sleep(3)
py.position()
# Out:
# Point(x=827, y=705)
